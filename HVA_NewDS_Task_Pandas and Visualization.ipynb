# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
food =pd.read_csv(r"C:\Users\sileo\Downloads\Indian_Food_Datasets(PyPandas_Task)\Ifood_new.csv")
food
# Out:
#                    name                                        ingredients  \
# 0             Adhirasam   Rice flour, jaggery, ghee, vegetable oil, elachi
# 1             Aloo gobi  Cauliflower, potato, garam masala, turmeric, c...
# 2            Aloo matar  Potato, peas, chillies, ginger, garam masala, ...
# 3            Aloo methi      Potato, fenugreek leaves, chillies, salt, oil
# 4     Aloo shimla mirch  Potato, shimla mirch, garam masala, amchur pow...
# ..                  ...                                                ...
# 250                Vada  Urad dal, ginger, curry leaves, green chilies,...
# 251       Veg Kolhapuri            Gobi, potato, beans, khus khus, coconut
# 252  Vegetable jalfrezi  Baby corn, french beans, garam masala, ginger,...
# 253            Vindaloo  Chicken, coconut oil, wine vinegar, ginger, gr...
# 254               Zunka  Gram flour, mustard, garlic, turmeric, red chilli
#
# ...

# %%
food.head(10)
# Out:
#                 name                                        ingredients  \
# 0          Adhirasam   Rice flour, jaggery, ghee, vegetable oil, elachi
# 1          Aloo gobi  Cauliflower, potato, garam masala, turmeric, c...
# 2         Aloo matar  Potato, peas, chillies, ginger, garam masala, ...
# 3         Aloo methi      Potato, fenugreek leaves, chillies, salt, oil
# 4  Aloo shimla mirch  Potato, shimla mirch, garam masala, amchur pow...
# 5         Aloo tikki  Rice flour, potato, bread crumbs, garam masala...
# 6         Alu Pitika        Potatoes, mustard oil, fish, green chillies
# 7               Amti  Kala masala, arhar dal, curry leaves, mustard ...
# 8             Anarsa               Rice flour, jaggery, khus-khus seeds
# 9            Ariselu                          Rice flour, jaggery, ghee
#
#              diet  prep_time  cook_time flavor_profile       course  \
# 0      vegetarian         10         50          sweet      dessert
# ...

# %%
food.tail(10)
# Out:
#                           name  \
# 245  Turiya Patra Vatana sabji
# 246                    Undhiyu
# 247                 Unni Appam
# 248                       Upma
# 249                    Uttapam
# 250                       Vada
# 251              Veg Kolhapuri
# 252         Vegetable jalfrezi
# 253                   Vindaloo
# 254                      Zunka
#
#                                            ingredients            diet  \
# 245  Ridge gourd, baking soda, sugar, grated coconu...      vegetarian
# 246  Sweet potato, surti papdi, baby potatoes, valo...      vegetarian
# 247               Rice flour, banana, jaggery, coconut      vegetarian
# 248   Chana dal, urad dal, ginger, curry leaves, sugar      vegetarian
# 249    Chana dal, urad dal, thick poha, tomato, butter      vegetarian
# 250  Urad dal, ginger, curry leaves, green chilies,...      vegetarian
# 251            Gobi, potato, beans, khus khus, coconut      vegetarian
# ...

# %%
food['name']
# Out:
# 0               Adhirasam
# 1               Aloo gobi
# 2              Aloo matar
# 3              Aloo methi
# 4       Aloo shimla mirch
#               ...
# 250                  Vada
# 251         Veg Kolhapuri
# 252    Vegetable jalfrezi
# 253              Vindaloo
# 254                 Zunka
# Name: name, Length: 255, dtype: object

# %%
food[['name']]
# Out:
#                    name
# 0             Adhirasam
# 1             Aloo gobi
# 2            Aloo matar
# 3            Aloo methi
# 4     Aloo shimla mirch
# ..                  ...
# 250                Vada
# 251       Veg Kolhapuri
# 252  Vegetable jalfrezi
# 253            Vindaloo
# 254               Zunka
#
# [255 rows x 1 columns]

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            255 non-null    object
#  1   ingredients     255 non-null    object
#  2   diet            255 non-null    object
#  3   prep_time       255 non-null    int64
#  4   cook_time       255 non-null    int64
#  5   flavor_profile  255 non-null    object
#  6   course          255 non-null    object
#  7   state           255 non-null    object
#  8   region          254 non-null    object
#  9   img_url         254 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 20.1+ KB

# %%
food.dtypes
# Out:
# name              object
# ingredients       object
# diet              object
# prep_time          int64
# cook_time          int64
# flavor_profile    object
# course            object
# state             object
# region            object
# img_url           object
# dtype: object

# %%
food.columns
# Out:
# Index(['name', 'ingredients', 'diet', 'prep_time', 'cook_time',
#        'flavor_profile', 'course', 'state', 'region', 'img_url'],
#       dtype='object')

# %%
food.values
# Out:
# array([['Adhirasam', 'Rice flour, jaggery, ghee, vegetable oil, elachi',
#         'vegetarian', ..., 'West Bengal', 'East',
#         'https://www.crazymasalafood.com/wp-content/images/adhirasam.jpg'],
#        ['Aloo gobi',
#         'Cauliflower, potato, garam masala, turmeric, curry leaves',
#         'vegetarian', ..., 'Punjab', 'North',
#         'https://www.vegrecipesofindia.com/wp-content/uploads/2013/11/gobi-masala-recipe-500x500.jpg'],
#        ['Aloo matar',
#         'Potato, peas, chillies, ginger, garam masala, garlic',
#         'vegetarian', ..., 'Punjab', 'North',
#         'https://www.vegrecipesofindia.com/wp-content/uploads/2013/12/aloo-matar-gravy-recipe-500x500.jpg'],
#        ...,
#        ['Vegetable jalfrezi',
#         'Baby corn, french beans, garam masala, ginger, carrot',
#         'vegetarian', ..., 'Punjab', 'North',
#         'https://www.vegrecipesofindia.com/wp-content/uploads/2014/05/paneer-veg-jalfrezi-recipe.jpg'],
#        ['Vindaloo',
# ...

# %%
food.region
# Out:
# 0       East
# 1      North
# 2      North
# 3      North
# 4      North
#        ...
# 250    South
# 251     West
# 252    North
# 253     West
# 254     West
# Name: region, Length: 255, dtype: object

# %%
food.count
# Out:
# <bound method DataFrame.count of                    name                                        ingredients  \
# 0             Adhirasam   Rice flour, jaggery, ghee, vegetable oil, elachi
# 1             Aloo gobi  Cauliflower, potato, garam masala, turmeric, c...
# 2            Aloo matar  Potato, peas, chillies, ginger, garam masala, ...
# 3            Aloo methi      Potato, fenugreek leaves, chillies, salt, oil
# 4     Aloo shimla mirch  Potato, shimla mirch, garam masala, amchur pow...
# ..                  ...                                                ...
# 250                Vada  Urad dal, ginger, curry leaves, green chilies,...
# 251       Veg Kolhapuri            Gobi, potato, beans, khus khus, coconut
# 252  Vegetable jalfrezi  Baby corn, french beans, garam masala, ginger,...
# 253            Vindaloo  Chicken, coconut oil, wine vinegar, ginger, gr...
# 254               Zunka  Gram flour, mustard, garlic, turmeric, red chilli
#
# ...

# %%
food.count()
# Out:
# name              255
# ingredients       255
# diet              255
# prep_time         255
# cook_time         255
# flavor_profile    255
# course            255
# state             255
# region            254
# img_url           254
# dtype: int64

# %%
food.shape
# Out:
# (255, 10)

# %%
food['region'].count()
# Out:
# 254

# %%
food["region"].value_counts()
# Out:
# region
# West          73
# South         58
# North         50
# East          32
# North East    25
# -1            13
# Central        3
# Name: count, dtype: int64

# %%
food.groupby("region").size()
# Out:
# region
# -1            13
# Central        3
# East          32
# North         50
# North East    25
# South         58
# West          73
# dtype: int64

# %%
food.groupby("region").count()
# Out:
#             name  ingredients  diet  prep_time  cook_time  flavor_profile  \
# region
# -1            13           13    13         13         13              13
# Central        3            3     3          3          3               3
# East          32           32    32         32         32              32
# North         50           50    50         50         50              50
# North East    25           25    25         25         25              25
# South         58           58    58         58         58              58
# West          73           73    73         73         73              73
#
#             course  state  img_url
# region
# -1              13     13       13
# Central          3      3        3
# East            32     32       32
# North           50     50       50
# North East      25     25       25
# South           58     58       57
# West            73     73       73

# %%
from collections import Counter
food_Group = Counter(food["region"])
food_Group
# Out:
# Counter({'West': 73,
#          'South': 58,
#          'North': 50,
#          'East': 32,
#          'North East': 25,
#          '-1': 13,
#          'Central': 3,
#          nan: 1})

# %%
food.isnull()
# Out:
#       name  ingredients   diet  prep_time  cook_time  flavor_profile  course  \
# 0    False        False  False      False      False           False   False
# 1    False        False  False      False      False           False   False
# 2    False        False  False      False      False           False   False
# 3    False        False  False      False      False           False   False
# 4    False        False  False      False      False           False   False
# ..     ...          ...    ...        ...        ...             ...     ...
# 250  False        False  False      False      False           False   False
# 251  False        False  False      False      False           False   False
# 252  False        False  False      False      False           False   False
# 253  False        False  False      False      False           False   False
# 254  False        False  False      False      False           False   False
#
#      state  region  img_url
# ...

# %%
food["name"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 250    False
# 251    False
# 252    False
# 253    False
# 254    False
# Name: name, Length: 255, dtype: bool

# %%
food["name"].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 250    False
# 251    False
# 252    False
# 253    False
# 254    False
# Name: name, Length: 255, dtype: bool

# %%
food.describe()
# Out:
#         prep_time   cook_time
# count  255.000000  255.000000
# mean    31.105882   34.529412
# std     72.554409   48.265650
# min     -1.000000   -1.000000
# 25%     10.000000   20.000000
# 50%     10.000000   30.000000
# 75%     20.000000   40.000000
# max    500.000000  720.000000

# %%
duplicateRows = food[food.duplicated()]
duplicateRows
# Out:
# Empty DataFrame
# Columns: [name, ingredients, diet, prep_time, cook_time, flavor_profile, course, state, region, img_url]
# Index: []

# %%
food.isnull().sum()
# Out:
# name              0
# ingredients       0
# diet              0
# prep_time         0
# cook_time         0
# flavor_profile    0
# course            0
# state             0
# region            1
# img_url           1
# dtype: int64

# %%
columns_with_missing = food.columns[food.isnull().any()]
columns_with_missing
# Out:
# Index(['region', 'img_url'], dtype='object')

# %%
print(food['region'].isnull())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 250    False
# 251    False
# 252    False
# 253    False
# 254    False
# Name: region, Length: 255, dtype: bool

# %%
print(food[food['region'].isnull()])
# Out:
#          name                                        ingredients        diet  \
# 177  Panjeeri  Whole wheat flour, musk melon seeds, poppy see...  vegetarian
#
#      prep_time  cook_time flavor_profile   course          state region  \
# 177         10         25          sweet  dessert  Uttar Pradesh    NaN
#
#                                                img_url
# 177  https://i0.wp.com/fatimacooks.net/wp-content/u...

# %%
food[food['img_url'].isnull()]
# Out:
#          name                   ingredients        diet  prep_time  cook_time  \
# 95  Kajjikaya  Rice flour, jaggery, coconut  vegetarian         40         15
#
#    flavor_profile   course           state region img_url
# 95          sweet  dessert  Andhra Pradesh  South     NaN

# %%
food["region"].fillna("NotUpdated", inplace = True)
food["img_url"].fillna("NotUpdated", inplace = True)
# Out:
# C:\Users\sileo\AppData\Local\Temp\ipykernel_17904\397972313.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   food["img_url"].fillna("NotUpdated", inplace = True)

# %%
food[food['img_url'].isnull()]
# Out:
# Empty DataFrame
# Columns: [name, ingredients, diet, prep_time, cook_time, flavor_profile, course, state, region, img_url]
# Index: []

# %%
food.iloc[95]
# Out:
# name                                 Kajjikaya
# ingredients       Rice flour, jaggery, coconut
# diet                                vegetarian
# prep_time                                   40
# cook_time                                   15
# flavor_profile                           sweet
# course                                 dessert
# state                           Andhra Pradesh
# region                                   South
# img_url                             NotUpdated
# Name: 95, dtype: object

# %%
food[food["region"]=="NotUpdated"]
# Out:
#          name                                        ingredients        diet  \
# 177  Panjeeri  Whole wheat flour, musk melon seeds, poppy see...  vegetarian
#
#      prep_time  cook_time flavor_profile   course          state      region  \
# 177         10         25          sweet  dessert  Uttar Pradesh  NotUpdated
#
#                                                img_url
# 177  https://i0.wp.com/fatimacooks.net/wp-content/u...

# %%
food.loc[food["region"]=="NotUpdated"]
# Out:
#          name                                        ingredients        diet  \
# 177  Panjeeri  Whole wheat flour, musk melon seeds, poppy see...  vegetarian
#
#      prep_time  cook_time flavor_profile   course          state      region  \
# 177         10         25          sweet  dessert  Uttar Pradesh  NotUpdated
#
#                                                img_url
# 177  https://i0.wp.com/fatimacooks.net/wp-content/u...

# %%
food.loc[food["img_url"]=="NotUpdated"]
# Out:
#          name                   ingredients        diet  prep_time  cook_time  \
# 95  Kajjikaya  Rice flour, jaggery, coconut  vegetarian         40         15
#
#    flavor_profile   course           state region     img_url
# 95          sweet  dessert  Andhra Pradesh  South  NotUpdated

# %%
#Select rows where the diet is "vegetarian" using .loc.
food.loc[food["diet"]=="vegetarian"]
# Out:
#                    name                                        ingredients  \
# 0             Adhirasam   Rice flour, jaggery, ghee, vegetable oil, elachi
# 1             Aloo gobi  Cauliflower, potato, garam masala, turmeric, c...
# 2            Aloo matar  Potato, peas, chillies, ginger, garam masala, ...
# 3            Aloo methi      Potato, fenugreek leaves, chillies, salt, oil
# 4     Aloo shimla mirch  Potato, shimla mirch, garam masala, amchur pow...
# ..                  ...                                                ...
# 249             Uttapam    Chana dal, urad dal, thick poha, tomato, butter
# 250                Vada  Urad dal, ginger, curry leaves, green chilies,...
# 251       Veg Kolhapuri            Gobi, potato, beans, khus khus, coconut
# 252  Vegetable jalfrezi  Baby corn, french beans, garam masala, ginger,...
# 254               Zunka  Gram flour, mustard, garlic, turmeric, red chilli
#
#            diet  prep_time  cook_time flavor_profile       course  \
# ...

# %%
food.loc[food["diet"]=="vegetarian"].count()
# Out:
# name              227
# ingredients       227
# diet              227
# prep_time         227
# cook_time         227
# flavor_profile    227
# course            227
# state             227
# region            227
# img_url           227
# dtype: int64

# %%
food1 = food[["name","region","prep_time"]]
food1
# Out:
#                    name region  prep_time
# 0             Adhirasam   East         10
# 1             Aloo gobi  North         10
# 2            Aloo matar  North          5
# 3            Aloo methi  North         10
# 4     Aloo shimla mirch  North         10
# ..                  ...    ...        ...
# 250                Vada  South         15
# 251       Veg Kolhapuri   West         20
# 252  Vegetable jalfrezi  North         10
# 253            Vindaloo   West         10
# 254               Zunka   West         10
#
# [255 rows x 3 columns]

# %%
#Select the name and region columns for dishes with a prep_time of less than 30 minutes using .loc.

food1.loc[food["prep_time"]<=30]
# Out:
#                    name region  prep_time
# 0             Adhirasam   East         10
# 1             Aloo gobi  North         10
# 2            Aloo matar  North          5
# 3            Aloo methi  North         10
# 4     Aloo shimla mirch  North         10
# ..                  ...    ...        ...
# 250                Vada  South         15
# 251       Veg Kolhapuri   West         20
# 252  Vegetable jalfrezi  North         10
# 253            Vindaloo   West         10
# 254               Zunka   West         10
#
# [224 rows x 3 columns]

# %%
#Select the first row of the data frame using .iloc.
food.iloc[1]
# Out:
# name                                                      Aloo gobi
# ingredients       Cauliflower, potato, garam masala, turmeric, c...
# diet                                                     vegetarian
# prep_time                                                        10
# cook_time                                                        20
# flavor_profile                                                spicy
# course                                                  main course
# state                                                        Punjab
# region                                                        North
# img_url           https://www.vegrecipesofindia.com/wp-content/u...
# Name: 1, dtype: object

# %%
#Select the first 10 rows and the name, diet, and region column(both loc and iloc)
f1 =food.loc[:,["name","diet"]]
f1
f1.iloc[1:11]
# Out:
#                  name            diet
# 1           Aloo gobi      vegetarian
# 2          Aloo matar      vegetarian
# 3          Aloo methi      vegetarian
# 4   Aloo shimla mirch      vegetarian
# 5          Aloo tikki      vegetarian
# 6          Alu Pitika  non vegetarian
# 7                Amti      vegetarian
# 8              Anarsa      vegetarian
# 9             Ariselu      vegetarian
# 10               Attu      vegetarian

# %%
#Set both the region and name columns as a multi-level index.
food.iloc[:5]
food.iloc[5:15]
food.iloc[[2,3,7]]
food.iloc[[2, 3, 5],[8, 0]]
food.iloc[5:10, [0, 1]]
# Out:
#          name                                        ingredients
# 5  Aloo tikki  Rice flour, potato, bread crumbs, garam masala...
# 6  Alu Pitika        Potatoes, mustard oil, fish, green chillies
# 7        Amti  Kala masala, arhar dal, curry leaves, mustard ...
# 8      Anarsa               Rice flour, jaggery, khus-khus seeds
# 9     Ariselu                          Rice flour, jaggery, ghee

# %%
#Drop rows where the index region is 'West'?
indexes = food[food["region"]=="West"].index
indexes
# Out:
# Index([  7,   8,  13,  16,  17,  19,  26,  27,  32,  35,  37,  49,  50,  51,
#         52,  54,  55,  57,  60,  62,  63,  64,  67,  70,  73,  76,  77,  79,
#         81,  83,  89, 100, 106, 107, 108, 109, 114, 119, 120, 125, 129, 139,
#        144, 145, 152, 157, 158, 161, 164, 184, 185, 186, 192, 195, 203, 214,
#        215, 221, 222, 226, 228, 229, 234, 235, 236, 237, 240, 243, 245, 246,
#        251, 253, 254],
#       dtype='int64')

# %%
food.drop(indexes,inplace = True)

# %%
food[food["region"]=="North"]
# Out:
#                              name  \
# 1                       Aloo gobi
# 2                      Aloo matar
# 3                      Aloo methi
# 4               Aloo shimla mirch
# 5                      Aloo tikki
# 12                    Baingan Fry
# 20                        Bhatura
# 21                  Bhindi masala
# 30                 Butter chicken
# 34                   Chana masala
# 42                  Chicken Tikka
# 43           Chicken Tikka masala
# 48                  Chole bhature
# 58                   Dal makhani
# 59                      Dal tadka
# 68                       Dum aloo
# 71                 Gajar ka halwa
# 88                         Jalebi
# 92                        Kachori
# 93                   Kadai paneer
# 94                   Kadhi pakoda
# 101                 Karela bharta
# 116                         Kofta
# 135                         Lassi
# 136                Lauki ke kofte
# 140                  Litti chokha
# ...

# %%
#Group the data by diet and calculate the average prep_time for each group.
food.groupby(["diet"])["prep_time"].mean()
# Out:
# diet
# non vegetarian    30.680000
# vegetarian        38.636943
# Name: prep_time, dtype: float64

# %%
#count the number of dishes for each combination of region and diet.
food.groupby(["region"])["diet"].count()
# Out:
# region
# -1            13
# Central        3
# East          32
# North         50
# North East    25
# NotUpdated     1
# South         58
# Name: diet, dtype: int64

# %%
#count the occurrences of each value in the region column.
food["region"].value_counts()
# Out:
# region
# South         58
# North         50
# East          32
# North East    25
# -1            13
# Central        3
# NotUpdated     1
# Name: count, dtype: int64

# %%
#Select rows where the diet is "vegetarian".
food[food["diet"]== "vegetarian"]
# Out:
#                    name                                        ingredients  \
# 0             Adhirasam   Rice flour, jaggery, ghee, vegetable oil, elachi
# 1             Aloo gobi  Cauliflower, potato, garam masala, turmeric, c...
# 2            Aloo matar  Potato, peas, chillies, ginger, garam masala, ...
# 3            Aloo methi      Potato, fenugreek leaves, chillies, salt, oil
# 4     Aloo shimla mirch  Potato, shimla mirch, garam masala, amchur pow...
# ..                  ...                                                ...
# 247          Unni Appam               Rice flour, banana, jaggery, coconut
# 248                Upma   Chana dal, urad dal, ginger, curry leaves, sugar
# 249             Uttapam    Chana dal, urad dal, thick poha, tomato, butter
# 250                Vada  Urad dal, ginger, curry leaves, green chilies,...
# 252  Vegetable jalfrezi  Baby corn, french beans, garam masala, ginger,...
#
#            diet  prep_time  cook_time flavor_profile       course  \
# ...

# %%
#The top 3 regions with the highest average cook_time.
food.groupby(["region"]) ["cook_time"].mean()
food.groupby(["region"]) ["cook_time"].mean().reset_index().sort_values(["cook_time"],ascending=False).head(3)
# Out:
#     region  cook_time
# 1  Central  48.333333
# 3    North  41.480000
# 2     East  36.937500

# %%
#select rows where the name contains the substring "Chicken".
food[food["name"].str.contains("Chicken")]
# Out:
#                      name                                        ingredients  \
# 41         Chicken razala  Chicken, dahi, sesame seeds, garam masala powd...
# 42          Chicken Tikka  Chicken, whole wheat bread, rice flour, garam ...
# 43   Chicken Tikka masala  Naan bread, tomato sauce, skinless chicken bre...
# 44        Chicken Varuval  Meat curry powder, chicken chunks, ginger, tom...
# 117        Koldil Chicken  Banana flower, chicken, green chili, mustard o...
# 238      Tandoori Chicken  Greek yogurt, garam masala, kasuri methi, mari...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 41   non vegetarian         10         35          spicy  main course
# 42   non vegetarian        120         45          spicy      starter
# 43   non vegetarian         10         50          spicy  main course
# 44   non vegetarian         10         35          spicy  main course
# 117  non vegetarian         -1         -1          spicy  main course
# ...

# %%
#Renaming the prep_time column to preparation_time.
food.rename(columns = {"prep_time":"preparation_time"}, inplace =True)
food.head(3)
# Out:
#          name                                        ingredients        diet  \
# 0   Adhirasam   Rice flour, jaggery, ghee, vegetable oil, elachi  vegetarian
# 1   Aloo gobi  Cauliflower, potato, garam masala, turmeric, c...  vegetarian
# 2  Aloo matar  Potato, peas, chillies, ginger, garam masala, ...  vegetarian
#
#    preparation_time  cook_time flavor_profile       course        state  \
# 0                10         50          sweet      dessert  West Bengal
# 1                10         20          spicy  main course       Punjab
# 2                 5         40          spicy  main course       Punjab
#
#   region                                            img_url
# 0   East  https://www.crazymasalafood.com/wp-content/ima...
# 1  North  https://www.vegrecipesofindia.com/wp-content/u...
# 2  North  https://www.vegrecipesofindia.com/wp-content/u...

# %%
#rename the columns cook_time to cooking_time and diet to diet_type in the DataFrame.
food.rename(columns ={"cook_time":"cooking_time","diet":"diet_type"}, inplace=True)
food.head(7)
# Out:
#                 name                                        ingredients  \
# 0          Adhirasam   Rice flour, jaggery, ghee, vegetable oil, elachi
# 1          Aloo gobi  Cauliflower, potato, garam masala, turmeric, c...
# 2         Aloo matar  Potato, peas, chillies, ginger, garam masala, ...
# 3         Aloo methi      Potato, fenugreek leaves, chillies, salt, oil
# 4  Aloo shimla mirch  Potato, shimla mirch, garam masala, amchur pow...
# 5         Aloo tikki  Rice flour, potato, bread crumbs, garam masala...
# 6         Alu Pitika        Potatoes, mustard oil, fish, green chillies
#
#         diet_type  preparation_time  cooking_time flavor_profile       course  \
# 0      vegetarian                10            50          sweet      dessert
# 1      vegetarian                10            20          spicy  main course
# 2      vegetarian                 5            40          spicy  main course
# 3      vegetarian                10            40         bitter  main course
# ...

# %%
#(df1:region: ['North', 'South', 'East', 'West'], value1: [10, 20, 30, 40])
d ={'region':['North', 'South', 'East', 'West'], 'value1': [10, 20, 30, 40]}
df1 = pd.DataFrame(d)
df1
# Out:
#   region  value1
# 0  North      10
# 1  South      20
# 2   East      30
# 3   West      40

# %%
#(df2:region: ['North', 'East', 'West'], value2: [100, 200, 300])
d1 = {'region': ['North', 'East', 'West'], 'value2': [100, 200, 300]}
df2 = pd.DataFrame(d1)
df2
# Out:
#   region  value2
# 0  North     100
# 1   East     200
# 2   West     300

# %%
#inner join between two DataFrames df1 and df2 on the column region.
joiningInner = pd.merge(df1,df2, on ="region", how = "inner")
joiningInner
# Out:
#   region  value1  value2
# 0  North      10     100
# 1   East      30     200
# 2   West      40     300

# %%
joiningLeft = pd.merge(df1,df2, on ="region", how = "left")
joiningLeft
# Out:
#   region  value1  value2
# 0  North      10   100.0
# 1  South      20     NaN
# 2   East      30   200.0
# 3   West      40   300.0

# %%
joiningRight = pd.merge(df1,df2, on ="region", how = "right")
joiningRight
# Out:
#   region  value1  value2
# 0  North      10     100
# 1   East      30     200
# 2   West      40     300

# %%
#full outer join between df1 and df2 on the column region.
joiningOuter = pd.merge(df1,df2, on ="region", how = "outer")
joiningOuter
# Out:
#   region  value1  value2
# 0   East      30   200.0
# 1  North      10   100.0
# 2  South      20     NaN
# 3   West      40   300.0

# %%
pip install xlsxwriter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#writer=pd.Excel_writer(r"C:\Users\sileo\Downloads\Indian_Food_Datasets(PyPandas_Task)\Ifood_new.csv")
import xlsxwriter
food.to_excel(r"C:\Users\sileo\Downloads\Indian_Food_Datasets(PyPandas_Task)\Ifood_new",sheet_name ="Food_data,xlsx",engine='xlsxwriter')

# %%
#Write the data frame to an Excel file.
food.to_excel("Food_data2.xlsx",engine='xlsxwriter')

# %%
#Write the Data Frame to a CSV file.
food.to_csv("Food_data1.csv")

# %%
food.to_excel("Food_data2.xlsx")

# %%
food.head(5)
# Out:
#                 name                                        ingredients  \
# 0          Adhirasam   Rice flour, jaggery, ghee, vegetable oil, elachi
# 1          Aloo gobi  Cauliflower, potato, garam masala, turmeric, c...
# 2         Aloo matar  Potato, peas, chillies, ginger, garam masala, ...
# 3         Aloo methi      Potato, fenugreek leaves, chillies, salt, oil
# 4  Aloo shimla mirch  Potato, shimla mirch, garam masala, amchur pow...
#
#     diet_type  preparation_time  cooking_time flavor_profile       course  \
# 0  vegetarian                10            50          sweet      dessert
# 1  vegetarian                10            20          spicy  main course
# 2  vegetarian                 5            40          spicy  main course
# 3  vegetarian                10            40         bitter  main course
# 4  vegetarian                10            40          spicy  main course
#
#          state region                                            img_url
# ...

# %%
#Create a line chart in Python using Matplotlib and Seaborn to visualize the average preparation time by diet type, using different colors, linestyles, markers for each line.
#Add labels and title to the charts (x, y, title, and also use legend)
import matplotlib.pyplot as plt
import seaborn as sn
pic1 = food.groupby(["diet_type"])["preparation_time"].mean()
pic1
# Out:
# diet_type
# non vegetarian    30.680000
# vegetarian        38.636943
# Name: preparation_time, dtype: float64

# %%
plt.plot(pic1,color ="green", ls =":",marker="o")

# %%
#Create a line chart in Python using Matplotlib to visualize the average preparation and cooking time by diet type (multiple lines)
#Add labels and title to the charts (x,y,title,and also use legend,grid)
#pic2 = food.groupby(['diet_type'])['preparation_time','coooking_time'].mean()
x= food["diet_type"]
y1= food['preparation_time'].mean()
y2 = food['cooking_time'].mean()
print(y1,y2)
# Out:
# 37.543956043956044 33.10989010989011

# %%
plt.plot(food['preparation_time'],ls ="-")
plt.plot(food['cooking_time'], color ="Green", ls =":")
plt.legend()
plt.show()
# Out:
# C:\Users\sileo\AppData\Local\Temp\ipykernel_17904\313780737.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
sn.lineplot(data=food, x='diet_type', y='preparation_time')
sn.lineplot(data=food, x='diet_type', y='cooking_time')
# Out:
# <Axes: xlabel='diet_type', ylabel='preparation_time'>

# %%
#Bar Chart (Matplotlib and Seaborn)
#Create a bar chart in Python using Matplotlib to show the count of dishes for each diet type (vegetarian and non-vegetarian) 
Count = food.groupby(["diet_type"])["name"].count()
Count
#plt.bar(Count)
#plt.bar(Count, height = 7)
# Out:
# diet_type
# non vegetarian     25
# vegetarian        157
# Name: name, dtype: int64

# %%
# Count the occurrences of each diet type
diet_counts = food['diet_type'].value_counts()

# Create the bar chart
plt.bar(diet_counts.index, diet_counts.values,color="DarkGreen")
plt.xlabel("diet_type",)
plt.ylabel("diet_Values")
plt.title("Types of Diet - Summary")
# Out:
# Text(0.5, 1.0, 'Types of Diet - Summary')

# %%
#vegetarian=green color bar, non-vegetarian=red color bar. Also label and title the graph.
ax =sn.countplot(data=food, x="diet_type")
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '157'), Text(0, 0, '25')]

# %%
#Create a horizontal bar chart in Python using Matplotlib to show the total number of dishes from each region (Apply above parameters also) 
x=food['region']
y=food[['name']].count()
#y
z= food.groupby(['region'])['name'].count()
z
#plt.plot(z)
#plt.barh(x,y)
# Out:
# region
# -1            13
# Central        3
# East          32
# North         50
# North East    25
# NotUpdated     1
# South         58
# Name: name, dtype: int64

# %%
f1 =food['region'].value_counts()
f1
# Out:
# region
# South         58
# North         50
# East          32
# North East    25
# -1            13
# Central        3
# NotUpdated     1
# Name: count, dtype: int64

# %%
f1.index
# Out:
# Index(['South', 'North', 'East', 'North East', '-1', 'Central', 'NotUpdated'], dtype='object', name='region')

# %%
f1.values
# Out:
# array([58, 50, 32, 25, 13,  3,  1], dtype=int64)

# %%
#Create a stacked bar chart in Python using Matplotlib, Seaborn to show the distribution of diet types within each region.
plt.barh(f1.index, f1.values,color="Purple")
# Out:
# <BarContainer object of 7 artists>

# %%
#Create a stacked bar chart in Python using Matplotlib, Seaborn to show the distribution of diet types within each region.
ax =sn.countplot(data=food, x='region')
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '32'),
#  Text(0, 0, '50'),
#  Text(0, 0, '25'),
#  Text(0, 0, '58'),
#  Text(0, 0, '13'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1')]

# %%
#Create a histogram in Python using Matplotlib to visualize the distribution of preparation times in the Indian Food Dataset.
#Use edgecolor, bins, labels, titles
sn.histplot(data = food, x="preparation_time",bins =10).set(title ="Distribution of Preparation")
# Out:
# [Text(0.5, 1.0, 'Distribution of Preparation')]

# %%
plt.hist(food["preparation_time"],color = "magenta")
# Out:
# (array([163.,   1.,   5.,   3.,   4.,   0.,   0.,   3.,   0.,   3.]),
#  array([ -1. ,  49.1,  99.2, 149.3, 199.4, 249.5, 299.6, 349.7, 399.8,
#         449.9, 500. ]),
#  <BarContainer object of 10 artists>)

# %%
#Create a histogram in Python using Matplotlib to visualize the distribution of preparation times with customized colors for the bars (using figure size=10, 6).
fig, ax = plt.subplots(figsize=(4, 5))
sn.histplot(data=food,x="preparation_time", ax=ax, bins =4, color ="grey")
# Out:
# <Axes: xlabel='preparation_time', ylabel='Count'>

# %%
#Create a scatter plot in Python using Matplotlib to visualize the relationship between preparation time and cooking time in the Indian Food Dataset. (Use labels and title)
import matplotlib.pyplot as plt
plt.scatter(x= food["preparation_time"], y =food["cooking_time"],
            c ="yellow", 
            linewidths = 1, 
            marker ="o", 
            edgecolor ="green")
plt.xlabel("Preparation_time")
plt.ylabel("Cooking_time")
plt.title(" Relationship between preparation time and cooking time in the Indian Food Dataset")
plt.show()

#seaborn Chart
sn.scatterplot(data =food,x= "preparation_time", y ="cooking_time")
sn.scatterplot(data =food,x= "preparation_time", y ="cooking_time").set(title ="Correlation between preparation time and cooking time")
# Out:
# [Text(0.5, 1.0, 'Correlation between preparation time and cooking time')]

# %%
#Create a scatter plot in Python using Matplotlib to visualize the relationship between preparation time and cooking time, with different colors for vegetarian and non-vegetarian dishes (vegetarian=green, non-vegetarian=red. Use grid)
color_palette =["Green","red"]
sn.scatterplot(data =food,x= "preparation_time", y ="cooking_time",palette =color_palette, hue="diet_type").set(title ="Correlation between preparation time and cooking time")
# Out:
# [Text(0.5, 1.0, 'Correlation between preparation time and cooking time')]

# %%
#Create a pie chart in Python using Matplotlib to show the distribution of diet types, with custom colors for each slice. (Choose colors accordingly, use startangle=140 and autopct)
food["diet_type"].value_counts()
food.groupby(["diet_type"]).count()
food["diet_type"].count()
food.groupby(["diet_type"])
#label=list(food["diet_type"])
#food["diet_type"].values
label =food["diet_type"].unique()
value = food["diet_type"].value_counts()
value
color =["purple","DarkGrey"]
plt.pie(x=food["diet_type"].value_counts(), labels = label,colors =color, autopct='%1.1f%%', startangle =140,shadow = True)
#plt.pie(x=food["diet_type"].value_counts(), shadow = True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1f1ba088980>,
# ...
#  [Text(0.4696548395387385, -0.9946981108345597, 'vegetarian'),
#   Text(-0.4696547929735582, 0.9946981328206886, 'non vegetarian')],
#  [Text(0.25617536702113003, -0.5425626059097598, '86.3%'),
#   Text(-0.25617534162194083, 0.5425626179021937, '13.7%')])

# %%
#Create a pie chart in Python using Matplotlib to show the distribution of diet types, with a shadow effect and a custom start angle, with one slice (non-vegetarian) exploded.
fig, ax = plt.subplots(figsize=(5,5))
color =["lightGreen","orange"]
plt.pie(x=food["diet_type"].value_counts(),
        wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'}, 
        labels = label, autopct='%1.1f%%', 
        shadow = True, startangle =30, colors = color, explode =(0,0.2))
# Out:
# ([<matplotlib.patches.Wedge at 0x1f1ba06dd00>,
# ...
#  [Text(-1.0953418901935525, -0.10112439659753542, 'vegetarian'),
#   Text(1.2944949667325307, 0.1195105899246783, 'non vegetarian')],
#  [Text(-0.5974592128328468, -0.05515876178047386, '86.3%'),
#   Text(0.7966122872200189, 0.07354497841518665, '13.7%')])

# %%
#Donut chart
plt.pie(x=food["diet_type"].value_counts(),
        wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'}, 
        labels = label, autopct='%1.1f%%', startangle =30, colors = color)
centre_circle = plt.Circle((0,0), 0.55, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# %%
#Donut chart - create a donut chart in Python using Matplotlib to show the distribution of diet types.
plt.pie(x=food["diet_type"].value_counts(),
        wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'}, 
        labels = label, autopct='%1.1f%%', startangle =30, colors = color, explode =(0,0.2))
centre_circle = plt.Circle((0,0), 0.55, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# %%
#Create a box plot in Python using Matplotlib to visualize the distribution of preparation times with proper axis labels and titles.

sn.boxplot(data= food, x="preparation_time",y ="diet_type", hue ="diet_type").set(title="distribution of Preparation_times")
# Out:
# [Text(0.5, 1.0, 'distribution of Preparation_times')]

# %%
#Create a box plot in Python using Matplotlib to visualize the distribution of preparation times for vegetarian and non-vegetarian dishes, with custom colors for each box (use medianprops, boxprops and try some other functions as well)

# %%
sn.violinplot(data= food, x="preparation_time",y ="diet_type", hue ="diet_type").set(title="distribution of Preparation_times")
# Out:
# [Text(0.5, 1.0, 'distribution of Preparation_times')]

# %%
food.head()
# Out:
#                 name                                        ingredients  \
# 0          Adhirasam   Rice flour, jaggery, ghee, vegetable oil, elachi
# 1          Aloo gobi  Cauliflower, potato, garam masala, turmeric, c...
# 2         Aloo matar  Potato, peas, chillies, ginger, garam masala, ...
# 3         Aloo methi      Potato, fenugreek leaves, chillies, salt, oil
# 4  Aloo shimla mirch  Potato, shimla mirch, garam masala, amchur pow...
#
#     diet_type  preparation_time  cooking_time flavor_profile       course  \
# 0  vegetarian                10            50          sweet      dessert
# 1  vegetarian                10            20          spicy  main course
# 2  vegetarian                 5            40          spicy  main course
# 3  vegetarian                10            40         bitter  main course
# 4  vegetarian                10            40          spicy  main course
#
#          state region                                            img_url
# ...

# %%
food[["ingredients","region"]]
# Out:
#                                            ingredients region
# 0     Rice flour, jaggery, ghee, vegetable oil, elachi   East
# 1    Cauliflower, potato, garam masala, turmeric, c...  North
# 2    Potato, peas, chillies, ginger, garam masala, ...  North
# 3        Potato, fenugreek leaves, chillies, salt, oil  North
# 4    Potato, shimla mirch, garam masala, amchur pow...  North
# ..                                                 ...    ...
# 247               Rice flour, banana, jaggery, coconut  South
# 248   Chana dal, urad dal, ginger, curry leaves, sugar     -1
# 249    Chana dal, urad dal, thick poha, tomato, butter  South
# 250  Urad dal, ginger, curry leaves, green chilies,...  South
# 252  Baby corn, french beans, garam masala, ginger,...  North
#
# [182 rows x 2 columns]

# %%
#Create a basic heatmap in Python using Matplotlib to visualize the number of ingredients in different regions(pivot table of the number of ingredients by region)
h1 = food[["ingredients","region"]]
h2 =h1.groupby(["region"])["ingredients"].count()
h2
# Out:
# region
# -1            13
# Central        3
# East          32
# North         50
# North East    25
# NotUpdated     1
# South         58
# Name: ingredients, dtype: int64

# %%
#Create a heatmap in Python using Seaborn to visualize the average preparation time for different regions, masking regions with fewer than 5 dishes (Create a pivot table and mask regions with fewer than 5 dishes, use mask, annot, fmt, cmap)
h3 =h1.groupby(["region"])["ingredients"].count().mean()
h3
# Out:
# 26.0

# %%
# Mask regions with fewer than 5 dishes
mask = pivot_table['count'] < 5

# Create a masked DataFrame for the heatmap
heatmap_data = pivot_table['mean']
heatmap_data = heatmap_data.mask(mask)

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(heatmap_data.to_frame().T, annot=True, fmt=".1f", cmap='viridis', mask=mask.to_frame().T)
plt.title('Average Preparation Time by Region')
plt.xlabel('Region')
plt.ylabel('')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[108], line 2
#       1 # Mask regions with fewer than 5 dishes
# ----> 2 mask = pivot_table['count'] < 5
#       4 # Create a masked DataFrame for the heatmap
#       5 heatmap_data = pivot_table['mean']
#
# NameError: name 'pivot_table' is not defined
